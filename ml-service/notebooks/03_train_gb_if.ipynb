# %% [markdown]
# # 03. Model Training: Gradient Boosting & Isolation Forest
# Trains supervised GradientBoostingClassifier and unsupervised IsolationForest models.

# %%
import pandas as pd
import joblib
from sklearn.ensemble import GradientBoostingClassifier, IsolationForest

# Load features
feature_cols = joblib.load('../models/feature_cols.pkl')
print('Features loaded:', feature_cols)
