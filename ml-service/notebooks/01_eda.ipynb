# %% [markdown]
# # 01. Exploratory Data Analysis (EDA) - PaySim Financial Transactions
# This notebook explores transaction distributions, class imbalance, and balance delta anomalies.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/paysim_subset.csv')
print('Dataset Shape:', df.shape)
df.head()

# %%
# Fraud Distribution by Transaction Type
df.groupby('type')['isFraud'].agg(['count', 'sum', 'mean'])
